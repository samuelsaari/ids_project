# %%
import pandas as pd
how_big_run="large" # "quick" "small" "medium" "large" "full" # data will be updated

def load_data(what:str,how_big_run=how_big_run):
    return pd.read_feather(f'./bgg_data/bgg_{what}_{how_big_run}.feather')


users = load_data("users")
games = load_data("games")
ratings = load_data("ratings")

ratings
# Out:
#          username  bgg_id                                       game_name  \
# 0      JustinKase   86003                                 Aether Captains
# 1      JustinKase   92186            Aether Captains: Pirates and Traders
# 2      JustinKase    1608                                         Ambush!
# 3      JustinKase  110277                                 Among the Stars
# 4      JustinKase     162         The Awful Green Things From Outer Space
# ...           ...     ...                                             ...
# 25447      258678  266121                      Unlock!: Heroic Adventures
# 25448      258678  163474                                      V-Sabotage
# 25449      258678   99120                The Walking Dead: The Board Game
# 25450      258678  196496  Warfighter: The WWII Tactical Combat Card Game
# 25451      258678  181521        Warhammer Quest: The Adventure Card Game
#
#        rating  owned  num_plays             collection_date  weight  \
# ...

# %%
games.query('name=="V-Sabotage"') # the game is not even fetched
# Out:
# Empty DataFrame
# Columns: [bgg_id, name, year, weight, avg_rating, num_ratings, categories, mechanics]
# Index: []

# %%
merged_df = ratings.merge(
    games,
    on='bbg_id',  # replace with your actual joining column
    how='left'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43036\3956668821.py in ?()
# ----> 1 merged_df = ratings.merge(
#       2     games,
#       3     on='bbg_id',  # replace with your actual joining column
#       4     how='left'
#
# c:\Users\mmak\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ...
