# %%
import pandas as pd
how_big_run="medium" # "quick" "small" "medium" "large" "full" # data will be updated. Let's use "full" when it is ready

def load_data(what:str,how_big_run=how_big_run):
    return pd.read_feather(f'./bgg_data/bgg_{what}_{how_big_run}.feather')


users = load_data("users")
games = load_data("games")
ratings = load_data("ratings")

# %%
l=["Economic", "Negotiation", "Political"]

", ".join(l)
# Out:
# 'Economic, Negotiation, Political'

# %%
games

games['categories'] = games['categories'].apply(lambda x: ", ".join(x))
games['mechanics'] = games['mechanics'].apply(lambda x: ", ".join(x))
games['mechanics'] = games['mechanics'].apply(lambda x: ", ".join(x))
games['avg_rating'] = games['avg_rating'].round(2)


games
# Out:
#        bgg_id              name  year  weight  avg_rating  num_ratings  \
# 0           1        Die Macher  1986  4.3103     7.58338         5945
# 1           2      Dragonmaster  1981  1.9643     6.66908          608
# 2           3           Samurai  1998  2.4416     7.47896        16874
# 3           4    Tal der Könige  1992  2.6875     6.61647          362
# 4           5           Acquire  1963  2.4917     7.35124        21566
# ...       ...               ...   ...     ...         ...          ...
# 15990   98046    Sake & Samurai  2011  2.2174     5.91894          198
# 15991   32526            Ithaka  2002  2.0000     5.70833           12
# 15992   32564             Abyss  2002  2.0000     5.57143            7
# 15993  163643     Dice Must Die  2014  1.0000     5.72222            9
# 15994  425787  Guards & Goblins  2024  1.6667     7.70000           20
#
#                                               categories  \
# 0                     [Economic, Negotiation, Political]
# 1                                   [Card Game, Fantasy]
# 2                          [Abstract Strategy, Medieval]
# 3                                              [Ancient]
# 4                         [Economic, Territory Building]
# ...                                                  ...
# 15990  [Card Game, Fighting, Humor, Medieval, Party G...
# 15991                                [Abstract Strategy]
# 15992                                [Abstract Strategy]
# 15993                                       [Dice, Math]
# 15994                            [Fantasy, Print & Play]
#
#                                                mechanics  \
# 0      [Alliances, Area Majority / Influence, Auction...
# 1                                         [Trick-taking]
# 2      [Area Majority / Influence, Hand Management, H...
# 3      [Action Points, Area Majority / Influence, Auc...
# 4      [Connections, End Game Bonuses, Hand Managemen...
# ...                                                  ...
# 15990                   [Hand Management, Open Drafting]
# 15991  [Pattern Building, Pattern Recognition, Point ...
# 15992                          [Point to Point Movement]
# 15993                                     [Dice Rolling]
# 15994                 [Pattern Building, Tile Placement]
#
#                                         categories_test
# 0                      Economic, Negotiation, Political
# 1                                    Card Game, Fantasy
# 2                           Abstract Strategy, Medieval
# 3                                               Ancient
# 4                          Economic, Territory Building
# ...                                                 ...
# 15990  Card Game, Fighting, Humor, Medieval, Party Game
# 15991                                 Abstract Strategy
# 15992                                 Abstract Strategy
# 15993                                        Dice, Math
# 15994                             Fantasy, Print & Play
#
# [15995 rows x 9 columns]
